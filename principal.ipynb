# %% [markdown]
# # Criando Metadados em DataFrame's a partir de json's
#
# *   Criar uma forma de representar os metadados com programação
# *   Ler as informações que eu tenho nos artefatos e sistematizá-las
# *   Juntar todas as informações em uma tabela
# *   Análise da qualidade dos metadados

# %% [markdown]
# # Criando lista de DataFrames de Metadados para Gestão de Dados

# %%
from pk_metadados import dfs

# %%
dataFrames = dfs("artefatos")

# %%
dataFrames
# Out:
#   tb_camada   tb_base_de_dados         tb_nome             tb_descricao  \
# 0    bronze  bz_data_science_a  previsoes_de_a  Previsões diárias de a.
# 1    bronze  bz_data_science_a  previsoes_de_a  Previsões diárias de a.
# 2    bronze  bz_data_science_a  previsoes_de_a  Previsões diárias de a.
# 3    bronze  bz_data_science_a  previsoes_de_a  Previsões diárias de a.
# 4    bronze  bz_data_science_a  previsoes_de_a  Previsões diárias de a.
# 0      ouro  gd_data_science_c  previsoes_de_c  Previsões diárias de c.
# 1      ouro  gd_data_science_c  previsoes_de_c  Previsões diárias de c.
# 2      ouro  gd_data_science_c  previsoes_de_c  Previsões diárias de c.
# 3      ouro  gd_data_science_c  previsoes_de_c  Previsões diárias de c.
# 4      ouro  gd_data_science_c  previsoes_de_c  Previsões diárias de c.
# 0     prata  sl_data_science_b  previsoes_de_b  Previsões diárias de b.
# 1     prata  sl_data_science_b  previsoes_de_b  Previsões diárias de b.
# ...
